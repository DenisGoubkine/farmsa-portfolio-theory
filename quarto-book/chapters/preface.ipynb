# %% [markdown]
# # Research Overview
#
# ## Purpose, Utility, and Comparative Design
#
# This chapter introduces the report as a comparative study of covariance estimation for portfolio construction. It states the problem, shows the testing framework, and presents the visual overview needed before turning to the estimator chapters.

# %% [markdown]
# ## The Problem
#
# Portfolio optimization depends on the covariance matrix. When that matrix is estimated poorly, the optimizer treats noise as structure and produces unstable allocations.
#
# This report compares four covariance estimators under a common backtest design on the same 50-stock U.S. large-cap universe. The goal is practical: determine how estimator choice changes portfolio behavior, risk, and out-of-sample performance.
#
# ### What This Report Does
#
# - It compares four covariance estimators inside the same portfolio-construction framework.
# - It keeps the data universe, lookback design, and evaluation logic fixed across methods.
# - It extends the comparison with a downside-risk chapter and a portfolio optimizer interface.
#
# ### Estimators Covered
#
# - **Shrinkage Estimation** using Ledoit-Wolf regularization.
# - **Eigenvalue Cleaning** using Random Matrix Theory.
# - **Factor Covariance** using CAPM and Fama-French structure.
# - **Dynamic Covariance** using DCC-GARCH style time variation.

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, warnings
import seaborn as sns
from scipy.optimize import minimize
warnings.filterwarnings('ignore')

prices  = pd.read_csv('data/prices.csv',  index_col=0, parse_dates=True)
returns = pd.read_csv('data/returns.csv', index_col=0, parse_dates=True)
N, T = returns.shape[1], returns.shape[0]
print(f"Universe: {N} assets × {T} days  ({returns.index[0].date()} → {returns.index[-1].date()})")

SECTOR_MAP = {
    'AAPL':'Tech','MSFT':'Tech','GOOGL':'Tech','NVDA':'Tech','ADBE':'Tech',
    'CRM':'Tech','INTC':'Tech','CSCO':'Tech',
    'JPM':'Fin','BAC':'Fin','GS':'Fin','MS':'Fin','BLK':'Fin','AXP':'Fin',
    'JNJ':'Health','UNH':'Health','PFE':'Health','ABBV':'Health','LLY':'Health','MRK':'Health',
    'AMZN':'Discr','HD':'Discr','MCD':'Discr','NKE':'Discr','SBUX':'Discr',
    'PG':'Staples','KO':'Staples','PEP':'Staples','COST':'Staples',
    'CAT':'Indust','HON':'Indust','UPS':'Indust','BA':'Indust',
    'XOM':'Energy','CVX':'Energy','COP':'Energy','SLB':'Energy',
    'META':'Comm','DIS':'Comm','NFLX':'Comm',
    'NEE':'Util','DUK':'Util','SO':'Util',
    'AMT':'RE','PLD':'RE','CCI':'RE',
    'LIN':'Mat','APD':'Mat','SHW':'Mat','ECL':'Mat',
}
COLORS = {
    'Equal Weight': '#94a3b8', 'Sample Cov':  '#2c5282',
    'Ledoit-Wolf':  '#7c3aed', 'RMT Cleaning':'#059669',
    'Fama-French':  '#d97706', 'DCC-GARCH':   '#c53030',
}

# Fama-French factors (needed for M3 estimator)
import os, urllib.request, zipfile, io
ff_cache = 'data/ff_factors.csv'
if os.path.exists(ff_cache):
    ff_factors = pd.read_csv(ff_cache, index_col=0, parse_dates=True)
else:
    url = 'https://mba.tuck.dartmouth.edu/pages/faculty/ken.french/ftp/F-F_Research_Data_Factors_daily_CSV.zip'
    z = zipfile.ZipFile(io.BytesIO(urllib.request.urlopen(url).read()))
    with z.open(z.namelist()[0]) as f: raw = f.read().decode('utf-8')
    ff_all = pd.read_csv(io.StringIO(raw), skiprows=4, index_col=0)
    ff_all = ff_all[pd.to_numeric(ff_all.index, errors='coerce').notna()]
    ff_all.index = pd.to_datetime(ff_all.index.astype(str).str.strip(), format='%Y%m%d')
    ff_factors = ff_all[(ff_all.index>='2018-01-01')&(ff_all.index<='2024-12-31')] / 100
    ff_factors.to_csv(ff_cache)

ff = ff_factors.loc[ff_factors.index.isin(returns.index)]
mkt_rf, smb, hml, rf = ff['Mkt-RF'], ff['SMB'], ff['HML'], ff['RF']
print("All data loaded ✓")
# Out:
# Universe: 50 assets × 1759 days  (2018-01-03 → 2024-12-30)
# All data loaded ✓

# %%
# ── The Baseline Problem: Sample Covariance Is Mostly Noise ─
cov_sample = returns.cov().values
eigvals = np.sort(np.linalg.eigvalsh(cov_sample))[::-1]
q = N / T
sigma2 = np.mean(np.diag(cov_sample))
lam_plus = sigma2 * (1 + np.sqrt(q))**2
n_signal = int(np.sum(eigvals > lam_plus))

fig, axes = plt.subplots(1, 2, figsize=(13, 4.5))

colors = ['#dc2626' if v > lam_plus else '#94a3b8' for v in eigvals]
axes[0].bar(range(1, N+1), eigvals, color=colors, alpha=0.85, width=0.8)
axes[0].axhline(lam_plus, color='#dc2626', ls='--', lw=1.2, label='Noise ceiling (Marchenko–Pastur)')
axes[0].set_xlabel('Eigenvalue rank'); axes[0].set_ylabel('Eigenvalue')
axes[0].set_title(f'Only {n_signal} of {N} eigenvalues carry real signal', fontweight='bold')
axes[0].legend(fontsize=8)

cum_var = np.cumsum(eigvals) / eigvals.sum() * 100
axes[1].plot(range(1, N+1), cum_var, 'o-', color='#2563eb', ms=4, lw=1.5)
axes[1].axhline(90, color='#dc2626', ls='--', lw=1, alpha=0.6, label='90%')
axes[1].fill_between(range(1, N+1), cum_var, alpha=0.08, color='#2563eb')
axes[1].set_xlabel('Components kept'); axes[1].set_ylabel('Cumulative variance (%)')
axes[1].set_title('Most variance sits in just a few components', fontweight='bold')
axes[1].legend(fontsize=8); axes[1].set_ylim(0, 105)

plt.suptitle('Why Sample Covariance Fails: 1,275 Parameters, Mostly Noise',
             fontsize=12, fontweight='bold', y=1.02)
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Four Approaches to the Same Problem
#
# Each estimator makes a different bet about where the noise is and how to remove it.
#
# **M1 — Ledoit-Wolf** blends the sample covariance with a structured target $F$ at an analytically optimal weight $\alpha^*$:
# $$\hat{\Sigma}_{LW} = \alpha^* F + (1-\alpha^*) S$$
# Conservative, assumption-light, and guaranteed to improve on the sample covariance asymptotically.
#
# **M2 — RMT Cleaning** keeps eigenvalues that carry real signal and replaces the rest with their mean. Marchenko–Pastur theory tells us exactly where the noise floor sits:
# $$\hat{\Sigma}_{RMT} = \sum_{i\,\in\,\text{signal}} \lambda_i v_i v_i^\top \;+\; \bar{\lambda}_{\text{noise}}\,I_{\text{noise}}$$
#
# **M3 — Fama-French** says stocks only co-move through exposure to three economic factors — market, size, and value. This cuts 1,275 parameters down to 206:
# $$\hat{\Sigma}_{FF3} = B\,\Sigma_f\,B^\top + D$$
#
# **M4 — DCC-GARCH** breaks the assumption that $\Sigma$ is constant. Each stock gets its own GARCH volatility model, and correlations are updated daily:
# $$H_t = D_t\,R_t\,D_t$$
# The most expressive approach — and the most sensitive to estimation error.

# %%
# ── M1: Ledoit-Wolf Shrinkage ──────────────────────────────
from sklearn.covariance import LedoitWolf
def estimate_lw(returns_df):
    """Shrink sample cov toward constant-correlation target. See M1 for full derivation."""
    return LedoitWolf().fit(returns_df.values).covariance_

# ── M2: RMT Eigenvalue Cleaning ────────────────────────────
def estimate_rmt(returns_df):
    """Replace noise eigenvalues (below Marchenko-Pastur bound) with their mean."""
    S = returns_df.cov().values
    T_, N_ = returns_df.shape
    q = N_ / T_
    sigma2 = np.mean(np.diag(S))
    lam_plus = sigma2 * (1 + np.sqrt(q))**2
    eigvals, eigvecs = np.linalg.eigh(S)
    noise = eigvals <= lam_plus
    cleaned = np.where(noise, eigvals[noise].mean() if noise.any() else sigma2, eigvals)
    return eigvecs @ np.diag(cleaned) @ eigvecs.T

# ── M3: Fama-French 3-Factor Model ─────────────────────────
def estimate_ff3(returns_df):
    """Σ = B Σ_f B' + D using market, SMB, HML factors. See M3 for full derivation."""
    dates = returns_df.index.intersection(ff.index)
    excess = returns_df.loc[dates].subtract(rf.loc[dates], axis=0)
    F = ff.loc[dates, ['Mkt-RF','SMB','HML']].values
    X = np.column_stack([np.ones(len(dates)), F])
    n = excess.shape[1]
    B, resid_var = np.zeros((n,3)), np.zeros(n)
    for i, col in enumerate(excess.columns):
        coefs = np.linalg.lstsq(X, excess[col].values, rcond=None)[0]
        B[i] = coefs[1:]
        resid_var[i] = np.var(excess[col].values - X @ coefs, ddof=1)
    return B @ np.cov(F, rowvar=False) @ B.T + np.diag(resid_var)

# ── M4: DCC-GARCH (EWMA proxy) ─────────────────────────────
def estimate_dcc(returns_df, lam=0.94):
    """Exponentially-weighted covariance — captures time-varying risk (see M4 for full DCC-GARCH)."""
    X = returns_df.values - returns_df.values.mean(axis=0)
    C = np.cov(X[:30].T) if len(X) >= 30 else np.eye(X.shape[1]) * 1e-4
    for t in range(len(X)):
        C = lam * C + (1-lam) * np.outer(X[t], X[t])
    return C + np.eye(X.shape[1]) * 1e-8

print("All four estimators defined ✓")
# Out:
# All four estimators defined ✓

# %%
def min_variance_portfolio(cov):
    n = cov.shape[0]; w0 = np.ones(n)/n
    res = minimize(lambda w: w @ cov @ w, w0, method='SLSQP',
                   bounds=[(0,1)]*n,
                   constraints=[{'type':'eq','fun':lambda w: w.sum()-1}],
                   options={'ftol':1e-12,'maxiter':1000})
    return res.x if res.success else w0

LOOKBACK, REBAL, MIN_HIST = 252, 21, 252
dates = returns.index[MIN_HIST:]
n = returns.shape[1]
strategies = ['Equal Weight','Sample Cov','Ledoit-Wolf','RMT Cleaning','Fama-French','DCC-GARCH']
pv  = {k: [1.0] for k in strategies}
cw  = {k: np.ones(n)/n for k in strategies}
w_last = {}

print("Running backtest...", end='', flush=True)
for i, date in enumerate(dates):
    idx = returns.index.get_loc(date)
    if i % REBAL == 0:
        win = returns.iloc[idx-LOOKBACK:idx]
        cw['Equal Weight']  = np.ones(n)/n
        cw['Sample Cov']    = min_variance_portfolio(win.cov().values)
        cw['Ledoit-Wolf']   = min_variance_portfolio(estimate_lw(win))
        cw['RMT Cleaning']  = min_variance_portfolio(estimate_rmt(win))
        cw['Fama-French']   = min_variance_portfolio(estimate_ff3(win))
        cw['DCC-GARCH']     = min_variance_portfolio(estimate_dcc(win))
    day_ret = returns.iloc[idx].values
    for k in strategies:
        pv[k].append(pv[k][-1] * (1 + cw[k] @ day_ret))
w_last = {k: cw[k].copy() for k in strategies}

portfolio_df = pd.DataFrame(pv, index=[dates[0]-pd.Timedelta(days=1)]+list(dates))
print(f" ✓  ({len(dates)} days, {len(dates)//REBAL} rebalances)")
# Out:
# Running backtest... ✓  (1507 days, 71 rebalances)

# %%
fig, ax = plt.subplots(figsize=(12, 5))
for k in strategies:
    lw = 1.5 if k != 'Equal Weight' else 1.0
    al = 1.0 if k != 'Equal Weight' else 0.5
    ax.plot(portfolio_df.index, portfolio_df[k], label=k, color=COLORS[k], lw=lw, alpha=al)
ax.set_ylabel('Portfolio value ($1 start)')
ax.set_title('Cumulative Performance — All Six Strategies', fontweight='bold', fontsize=13)
ax.legend(ncol=2, fontsize=9, loc='upper left')
ax.grid(True, alpha=0.2)
plt.tight_layout(); plt.show()

def metrics(v):
    r = v.pct_change().dropna()
    ar, av = r.mean()*252, r.std()*np.sqrt(252)
    return {'Ann. Return (%)': ar*100, 'Ann. Vol (%)': av*100,
            'Sharpe': ar/av if av>0 else 0,
            'Max DD (%)': ((v/v.cummax())-1).min()*100}

display(pd.DataFrame({k: metrics(portfolio_df[k]) for k in strategies}).T.round(2)
        .style.background_gradient(subset=['Sharpe'], cmap='RdYlGn')
              .background_gradient(subset=['Ann. Vol (%)'], cmap='YlOrRd_r'))
# Out:
# <style type="text/css">
# #T_96491_row0_col1 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_96491_row0_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_96491_row1_col1 {
#   background-color: #910026;
#   color: #f1f1f1;
# }
# #T_96491_row1_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_96491_row2_col1 {
#   background-color: #820026;
#   color: #f1f1f1;
# }
# #T_96491_row2_col2 {
#   background-color: #d02927;
#   color: #f1f1f1;
# }
# #T_96491_row3_col1 {
#   background-color: #a80026;
#   color: #f1f1f1;
# }
# #T_96491_row3_col2 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_96491_row4_col1 {
#   background-color: #d9131f;
#   color: #f1f1f1;
# }
# #T_96491_row4_col2 {
#   background-color: #f99355;
#   color: #000000;
# }
# #T_96491_row5_col1 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_96491_row5_col2 {
#   background-color: #51b35e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_96491">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96491_level0_col0" class="col_heading level0 col0" >Ann. Return (%)</th>
#       <th id="T_96491_level0_col1" class="col_heading level0 col1" >Ann. Vol (%)</th>
#       <th id="T_96491_level0_col2" class="col_heading level0 col2" >Sharpe</th>
#       <th id="T_96491_level0_col3" class="col_heading level0 col3" >Max DD (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96491_level0_row0" class="row_heading level0 row0" >Equal Weight</th>
#       <td id="T_96491_row0_col0" class="data row0 col0" >19.000000</td>
#       <td id="T_96491_row0_col1" class="data row0 col1" >19.860000</td>
#       <td id="T_96491_row0_col2" class="data row0 col2" >0.960000</td>
#       <td id="T_96491_row0_col3" class="data row0 col3" >-34.270000</td>
#     </tr>
#     <tr>
#       <th id="T_96491_level0_row1" class="row_heading level0 row1" >Sample Cov</th>
#       <td id="T_96491_row1_col0" class="data row1 col0" >12.580000</td>
#       <td id="T_96491_row1_col1" class="data row1 col1" >17.190000</td>
#       <td id="T_96491_row1_col2" class="data row1 col2" >0.730000</td>
#       <td id="T_96491_row1_col3" class="data row1 col3" >-33.960000</td>
#     </tr>
#     <tr>
#       <th id="T_96491_level0_row2" class="row_heading level0 row2" >Ledoit-Wolf</th>
#       <td id="T_96491_row2_col0" class="data row2 col0" >12.880000</td>
#       <td id="T_96491_row2_col1" class="data row2 col1" >17.110000</td>
#       <td id="T_96491_row2_col2" class="data row2 col2" >0.750000</td>
#       <td id="T_96491_row2_col3" class="data row2 col3" >-33.980000</td>
#     </tr>
#     <tr>
#       <th id="T_96491_level0_row3" class="row_heading level0 row3" >RMT Cleaning</th>
#       <td id="T_96491_row3_col0" class="data row3 col0" >13.990000</td>
#       <td id="T_96491_row3_col1" class="data row3 col1" >17.320000</td>
#       <td id="T_96491_row3_col2" class="data row3 col2" >0.810000</td>
#       <td id="T_96491_row3_col3" class="data row3 col3" >-35.090000</td>
#     </tr>
#     <tr>
#       <th id="T_96491_level0_row4" class="row_heading level0 row4" >Fama-French</th>
#       <td id="T_96491_row4_col0" class="data row4 col0" >14.020000</td>
#       <td id="T_96491_row4_col1" class="data row4 col1" >17.690000</td>
#       <td id="T_96491_row4_col2" class="data row4 col2" >0.790000</td>
#       <td id="T_96491_row4_col3" class="data row4 col3" >-34.420000</td>
#     </tr>
#     <tr>
#       <th id="T_96491_level0_row5" class="row_heading level0 row5" >DCC-GARCH</th>
#       <td id="T_96491_row5_col0" class="data row5 col0" >15.690000</td>
#       <td id="T_96491_row5_col1" class="data row5 col1" >17.090000</td>
#       <td id="T_96491_row5_col2" class="data row5 col2" >0.920000</td>
#       <td id="T_96491_row5_col3" class="data row5 col3" >-27.510000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# ── Risk Over Time ─────────────────────────────────────────
fig, axes = plt.subplots(2, 1, figsize=(12, 7), sharex=True)

for k in strategies:
    vol = portfolio_df[k].pct_change().rolling(63).std() * np.sqrt(252) * 100
    axes[0].plot(portfolio_df.index, vol, color=COLORS[k], lw=1.3, alpha=0.85, label=k)
axes[0].axvspan(pd.Timestamp('2020-02-20'), pd.Timestamp('2020-04-03'),
                alpha=0.1, color='red')
axes[0].annotate('COVID crash', xy=(pd.Timestamp('2020-03-10'), 0),
                 xytext=(pd.Timestamp('2020-06-01'), axes[0].get_ylim()[1]*0.85 if axes[0].get_ylim()[1] > 0 else 40),
                 fontsize=8, color='#dc2626')
axes[0].set_ylabel('Rolling 3M Volatility (%)')
axes[0].set_title('How Each Estimator Handles Market Turbulence', fontweight='bold')
axes[0].legend(ncol=3, fontsize=8); axes[0].grid(True, alpha=0.2)

for k in strategies:
    dd = (portfolio_df[k] / portfolio_df[k].cummax() - 1) * 100
    axes[1].plot(portfolio_df.index, dd, color=COLORS[k], lw=1.3, alpha=0.85)
axes[1].axvspan(pd.Timestamp('2020-02-20'), pd.Timestamp('2020-04-03'),
                alpha=0.1, color='red')
axes[1].set_ylabel('Drawdown (%)')
axes[1].set_title('Drawdown Paths', fontweight='bold')
axes[1].grid(True, alpha=0.2)

plt.tight_layout(); plt.show()

# %%
# ── Portfolio Concentration at Last Rebalance ──────────────
hhi = {k: np.sum(w_last[k]**2) for k in strategies}

fig, axes = plt.subplots(1, 2, figsize=(13, 4.5))

axes[0].barh(list(hhi.keys()), list(hhi.values()),
             color=[COLORS[k] for k in strategies], alpha=0.85)
axes[0].axvline(1/N, color='black', ls='--', lw=1, label=f'1/N = {1/N:.3f}')
axes[0].set_xlabel('HHI  (lower = more spread out)')
axes[0].set_title('Portfolio Concentration', fontweight='bold')
axes[0].legend(fontsize=8); axes[0].grid(True, axis='x', alpha=0.2)

bp = axes[1].boxplot([w_last[k] for k in strategies], vert=False,
                     labels=strategies, patch_artist=True, widths=0.5)
for patch, k in zip(bp['boxes'], strategies):
    patch.set_facecolor(COLORS[k]); patch.set_alpha(0.6)
axes[1].axvline(1/N, color='black', ls='--', lw=1)
axes[1].set_xlabel('Portfolio weight')
axes[1].set_title('Weight Distribution — Last Rebalance', fontweight='bold')
axes[1].grid(True, axis='x', alpha=0.2)

plt.tight_layout(); plt.show()

print("HHI (1/N baseline = {:.4f}):".format(1/N))
for k in strategies:
    print(f"  {k:16s}  {hhi[k]:.4f}  ({np.sum(w_last[k]>0.01)}/{N} positions > 1%)")
# Out:
# HHI (1/N baseline = 0.0200):
#   Equal Weight      0.0200  (50/50 positions > 1%)
#   Sample Cov        0.0729  (23/50 positions > 1%)
#   Ledoit-Wolf       0.0489  (26/50 positions > 1%)
#   RMT Cleaning      0.0493  (23/50 positions > 1%)
#   Fama-French       0.0633  (21/50 positions > 1%)
#   DCC-GARCH         0.0902  (17/50 positions > 1%)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Key Takeaways
#
# **All four estimators reduce portfolio risk relative to the raw sample covariance.** The optimizer can't exploit noise that isn't there — constraining the parameter space produces more stable portfolios. The difference between methods is usually smaller than the gap between any of them and the sample covariance baseline.
#
# **Shrinkage (LW) and RMT are the most reliable defaults.** They make minimal assumptions — just that the sample covariance has noise — and tend to work robustly across market regimes. If you don't have strong structural views about the data, start here.
#
# **Factor models (FF3) work best when you have economic conviction.** The Fama-French factors explain co-movement well for large-cap US stocks, and the reduced parameter count (206 vs 1,275) forces more diversified portfolios. The risk: any co-movement that doesn't flow through the three factors gets ignored.
#
# **Time-varying covariance (DCC-GARCH) captures what static models miss.** Correlations spike during crises — March 2020 being the clearest example in this dataset. Models that adapt in real time can reduce drawdowns. The cost is more parameters and a risk of over-reacting to recent history in calm periods.
#
# The right estimator depends on what kind of estimation error you're willing to accept. For the full derivation and analysis of each approach, see the individual module notebooks.

# %% [markdown]
# <p style='text-align:center; color:#8fadc8; font-style:italic; font-size:0.85em;'>
# Individual modules &mdash;
# <a href='M1_ledoit_wolf.ipynb'>M1: Ledoit-Wolf</a> &nbsp;&bull;&nbsp;
# <a href='M2_rmt_cleaning.ipynb'>M2: RMT Cleaning</a> &nbsp;&bull;&nbsp;
# <a href='M3_factor_models.ipynb'>M3: Fama-French</a> &nbsp;&bull;&nbsp;
# <a href='M4_dcc_garch.ipynb'>M4: DCC-GARCH</a>
# </p>
